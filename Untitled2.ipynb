# %%
import cobra
from cobra.io import load_model
from pathlib import Path
from cobra.io import load_json_model, save_json_model, load_matlab_model, save_matlab_model, read_sbml_model, write_sbml_model
import logging
import pandas as pd
from cobra import Model, Reaction, Metabolite
from cobra.io import write_sbml_model, validate_sbml_model

# %%
# %cd C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\MODELS\OTHER_SPECIES\Phaseolus vulgaris
pvulModel=read_sbml_model('pvulModel_CheckError2.txt')
# Out:
# C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\MODELS\OTHER_SPECIES\Phaseolus vulgaris
# No objective in listOfObjectives
# No objective coefficients in model. Unclear what should be optimized

# %%
pvulModel.metabolites.get_by_id('ARG[c]')
# Out:
# <Metabolite ARG[c] at 0x23dac213f40>

# %%
# %cd C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\MODELS\OTHER_SPECIES\Phaseolus vulgaris\SUPPORT
with open('exchange_reactions.txt','r') as f:
    list=f.readlines()
# Out:
# C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\MODELS\OTHER_SPECIES\Phaseolus vulgaris\SUPPORT

# %%
for i in range(len(list)):
    list[i]=list[i].replace(" ", "")
# Out:
# ARG
# ASCORBATE
# CIT
# CO-A
# CONIFERYL-ALCOHOL
# COUMARYL-ALCOHOL
# CYS
# FAD
# GLC
# GLN
# GLT
# GLY
# HIS
# ILE
# L-ALPHA-ALANINE
# L-ASPARTATE
# LEU
# LINOLEIC_ACID
# LINOLENIC_ACID
# LYS
# MAL
# MET
# OLEATE-CPD
# OXYGEN-MOLECULE
# PALMITATE
# PHE
# Pi
# PRO
# PROTON
# SER
# SINAPYL-ALCOHOL
# STEARIC_ACID
# SUC
# SUCROSE
# THF
# THR
# TRP
# TYR
# VAL
# WATER
# SULFATE

# %%
exchangeModel=Model('Exchange')
for i in list:
    exchangeModel.add_metabolites(pvulModel.metabolites.get_by_id(i+'[c]'))

# %%
for j in exchangeModel.metabolites:
    j.compartment='e'
    j.id=j.id.replace("[c]","[e]")
# Out:
# ARG[c]
# ASCORBATE[c]
# CIT[c]
# CO-A[c]
# CONIFERYL-ALCOHOL[c]
# COUMARYL-ALCOHOL[c]
# CYS[c]
# FAD[c]
# GLC[c]
# GLN[c]
# GLT[c]
# GLY[c]
# HIS[c]
# ILE[c]
# L-ALPHA-ALANINE[c]
# L-ASPARTATE[c]
# LEU[c]
# LINOLEIC_ACID[c]
# LINOLENIC_ACID[c]
# LYS[c]
# MAL[c]
# MET[c]
# OLEATE-CPD[c]
# OXYGEN-MOLECULE[c]
# PALMITATE[c]
# PHE[c]
# Pi[c]
# PRO[c]
# PROTON[c]
# SER[c]
# SINAPYL-ALCOHOL[c]
# STEARIC_ACID[c]
# SUC[c]
# SUCROSE[c]
# THF[c]
# THR[c]
# TRP[c]
# TYR[c]
# VAL[c]
# WATER[c]
# SULFATE[c]

# %%
for k in exchangeModel.metabolites:
    k.reactions=''
    print(k.id)
    print(k.compartment)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13140\1854552533.py in <module>
#       1 for k in exchangeModel.metabolites:
# ----> 2     k.reactions=''
#       3     print(k.id)
#       4     print(k.compartment)
#
# AttributeError: can't set attribute

# %%
exchangeModel
# Out:
# <Model Exchange at 0x23da8518a90>

# %%
# %cd C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\MODELS\OTHER_SPECIES\Arabidopsis thaliana\ARAGEM
aragem=read_sbml_model('AraGEM.xml')
# Out:
# C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\MODELS\OTHER_SPECIES\Arabidopsis thaliana\ARAGEM
# Model does not contain SBML fbc package information.
# '' is not a valid SBML 'SId'.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Adding exchange reaction EX_S_5_45_Amino_45_6_45__40_1_45_D_45_ribitylamino_41_uracil_c_b with default bounds for boundary metabolite: S_5_45_Amino_45_6_45__40_1_45_D_45_ribitylamino_41_uracil_c_b.
# Adding exchange reaction EX_S_6_45_Carboxyhexanoate_c_b with default bounds for boundary metabolite: S_6_45_Carboxyhexanoate_c_b.
# Adding exchange reaction EX_S_Acyl_45_carrier_32_protein_c_b with default bounds for boundary metabolite: S_Acyl_45_carrier_32_protein_c_b.
# Adding exchange reaction EX_S_Acyl_45_carrier_32_protein_p_b with default bounds for boundary metabolite: S_Acyl_45_carrier_32_protein_p_b.
# ...

# %%
for i in aragem.exchanges:
    print(i)
    print(i.bounds)
# Out:
# EX_S_5_45_Amino_45_6_45__40_1_45_D_45_ribitylamino_41_uracil_c_b: S_5_45_Amino_45_6_45__40_1_45_D_45_ribitylamino_41_uracil_c_b <=>
# (-1000.0, 1000.0)
# EX_S_6_45_Carboxyhexanoate_c_b: S_6_45_Carboxyhexanoate_c_b <=>
# (-1000.0, 1000.0)
# EX_S_Acyl_45_carrier_32_protein_c_b: S_Acyl_45_carrier_32_protein_c_b <=>
# (-1000.0, 1000.0)
# EX_S_Acyl_45_carrier_32_protein_p_b: S_Acyl_45_carrier_32_protein_p_b <=>
# (-1000.0, 1000.0)
# EX_S_Biomass_biomass_b: S_Biomass_biomass_b <=>
# (-1000.0, 1000.0)
# EX_S_Biotin_biomass_b: S_Biotin_biomass_b <=>
# (-1000.0, 1000.0)
# EX_S_CO2_ext_b: S_CO2_ext_b <=>
# (-1000.0, 1000.0)
# EX_S_Chlorophyll_32_a_biomass_b: S_Chlorophyll_32_a_biomass_b <=>
# (-1000.0, 1000.0)
# EX_S_CoA_biomass_b: S_CoA_biomass_b <=>
# (-1000.0, 1000.0)
# EX_S_Enzyme_32_N6_45__40_dihydrolipoyl_41_lysine_m_b: S_Enzyme_32_N6_45__40_dihydrolipoyl_41_lysine_m_b <=>
# (-1000.0, 1000.0)
# EX_S_Folate_biomass_b: S_Folate_biomass_b <=>
# (-1000.0, 1000.0)
# ...
