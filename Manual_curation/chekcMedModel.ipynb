# %%
import cobra
from cobra.io import load_model
from pathlib import Path
from cobra.io import load_json_model, save_json_model, load_matlab_model, save_matlab_model, read_sbml_model, write_sbml_model
import logging
import pandas as pd
from cobra import Model, Reaction, Metabolite
from cobra.io import write_sbml_model, validate_sbml_model

# %cd C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\MODELS\OTHER_SPECIES\Medicago truncatula.
medicagoModel=read_sbml_model('MedicagoTruncatula_Cobra_model.xml')
# Out:
# C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\MODELS\OTHER_SPECIES\Medicago truncatula

# %%
medicagoModel.compartments
# Out:
# {'H': 'Chloroplast',
#  'C': 'Cytosol',
#  'V': 'Vacuole',
#  'R': 'Endoplasmatic Reticulum',
#  'X': 'Peroxisome',
#  'L': 'Lumen',
#  'M': 'Mitochondrion',
#  'G': 'Golgi Apparatus'}

# %%
medicagoModel.summary()
# Out:
# <h3>Objective</h3><p>1.0 TEC_AMMONIUM + 1.0 TEC_CARBON-DIOXIDE + 1.0 TEC_CO+2 + 1.0 TEC_CPD-3 + 1.0 TEC_FE+2 + 1.0 TEC_GLC + 1.0 TEC_MG+2 + 1.0 TEC_NITRATE + 1.0 TEC_OXYGEN-MOLECULE + 1.0 TEC_Pi + 1.0 TEC_SUCROSE + 1.0 TEC_SULFATE + 1.0 TEC_WATER + 1.0 TEH_Light + 1.0 TEH_Starch + 1.0 ARGCons_tx + 1.0 ASNCons_tx + 1.0 CYSCons_tx + 1.0 GLNCons_tx + 1.0 GLTCons_tx + 1.0 GLYCons_tx + 1.0 HISCons_tx + 1.0 ILECons_tx + 1.0 L-ALPHA-ALANINECons_tx + 1.0 L-ASPARTATECons_tx + 1.0 LEUCons_tx + 1.0 LYSCons_tx + 1.0 METCons_tx + 1.0 PHECons_tx + 1.0 PROCons_tx + 1.0 TCE_ADENOSYL-HOMO-CYS + 1.0 TCE_ARG + 1.0 TCE_ASCORBATE + 1.0 TCE_ASN + 1.0 TCE_ATP + 1.0 TCE_BETA-D-FRUCTOSE + 1.0 TCE_CARBON-DIOXIDE + 1.0 TCE_CHOLINE + 1.0 TCE_CIT + 1.0 TCE_CO-A + 1.0 TCE_CONIFERYL-ALCOHOL + 1.0 TCE_COUMARYL-ALCOHOL + 1.0 TCE_CPD-8046 + 1.0 TCE_CTP + 1.0 TCE_CYS + 1.0 TCE_DATP + 1.0 TCE_DCTP + 1.0 TCE_DGTP + 1.0 TCE_FAD + 1.0 TCE_GLC + 1.0 TCE_GLN + 1.0 TCE_GLT + 1.0 TCE_GLY + 1.0 TCE_GTP + 1.0 TCE_HCO3 + 1.0 TCE
# ...

# %%
for i in medicagoModel.metabolites:
    if "CO+2" in i.id:
        for j in i.reactions:
            print(i,j.reaction)
# Out:
# CO+2[C] CO+2[C] + SIROHYDROCHLORIN[C] <=> COBALT-SIROHYDROCHLORIN[C] + 2.0 PROTON[C]
# CO+2[C]  --> CO+2[C]
# CO+2[C] CO+2[H] + 2.0 PROTON[C] <=> CO+2[C] + 2.0 PROTON[H]
# CO+2[H] CO+2[H] + SIROHYDROCHLORIN[H] <=> COBALT-SIROHYDROCHLORIN[H] + 2.0 PROTON[H]
# CO+2[H] CO+2[H] + 2.0 PROTON[C] <=> CO+2[C] + 2.0 PROTON[H]

# %%
medicagoModel.reactions.get_by_id('THC_CO+2')
# Out:
# <Reaction THC_CO+2 at 0x1e1e0f73f40>

# %%
medicagoModel.metabolites.get_by_id('CO+2[C]')
# Out:
# <Metabolite CO+2[C] at 0x1e1e082eef0>

# %%
medicagoModel.objective='BiomassShoot'

# %%
cobra.flux_analysis.find_blocked_reactions(medicagoModel)
# Out:
# ['TEC_CO+2',
#  'TEC_CPD-3',
#  'TCR_ADP',
#  'TCR_ALLANTOATE',
#  'TCR_ATP',
#  'TCR_CDP',
#  'TCR_CHOLINE',
#  'TCR_CO2',
#  'TCR_CPD-166',
#  'TCR_CTP',
#  'TCR_DOLICHOLP',
#  'TCR_FARNESYL-PP',
#  'TCR_GLYCEROL-3P',
#  'TCR_Lipid',
#  'TCR_OLEATE-CPD',
#  'TCR_OXYGEN',
#  'TCR_PALMITYL-COA',
#  'TCR_S-ALLANTOIN',
#  'TCR_SAM',
#  'TCR_STEAROYL-COA',
#  'TCR_WATER',
#  'TCR_ZYMOSTEROL',
#  'TCV_CPD-6747',
#  'TCV_INOSITOL-1-3-4-TRIPHOSPHATE',
#  'TCX_CO-A',
#  'TCX_CPD-730',
#  'TCX_CPD-734',
#  'TCX_DIHYDROXYNAPHTHOATE',
#  'TCX_O-SUCCINYLBENZOATE',
#  'TCX_TRYPTAMINE',
#  'TGC_OXYGEN-MOLECULE',
#  'TGC_PECTATE',
#  'THC_ANTHRANILATE',
#  'THC_BILIVERDINE',
#  'THC_CHOLINE',
#  'THC_CO+2',
#  'THC_CPD-12815',
#  'THC_CPD-7279',
#  'THC_CPD-729',
#  'THC_CPD1F-128',
#  'THC_CPD66-34',
#  'THC_CTP',
#  'THC_DELTA3-ISOPENTENYL-PP',
#  'THC_DI-H-OROTATE',
#  'THC_FAD',
#  'THC_HOMOGENTISATE',
#  'THC_INDOLE_ACETATE_AUXIN',
#  'THC_MTOB',
#  'THC_NICOTINATE_NUCLEOTIDE',
# ...
