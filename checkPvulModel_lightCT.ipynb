# %%
import cobra
from cobra.io import load_model
from pathlib import Path
from cobra.io import load_json_model, save_json_model, load_matlab_model, save_matlab_model, read_sbml_model, write_sbml_model
import logging
import pandas as pd
from cobra import Model, Reaction, Metabolite
from cobra.io import write_sbml_model, validate_sbml_model
# %cd C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\MODELS\OTHER_SPECIES\Phaseolus vulgaris
pvulModel=read_sbml_model('pvulModel_lightCT.xml')
# Out:
# C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\MODELS\OTHER_SPECIES\Phaseolus vulgaris

# %% [markdown]
# ## BIOMASS SIN LUZ

# %%
pvulModel.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass = 0.47959138499584725</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ASN[e]</td>
#       <td>EX_ASN[e]</td>
#       <td>508.3</td>
#       <td>4</td>
#       <td>6.32%</td>
#     </tr>
#     <tr>
#       <td>BETA-D-FRUCTOSE[e]</td>
#       <td>EX_BETA-D-FRUCTOSE[e]</td>
#       <td>5.142</td>
#       <td>6</td>
#       <td>0.10%</td>
#     </tr>
#     <tr>
#       <td>CIT[e]</td>
#       <td>EX_CIT[e]</td>
#       <td>366</td>
#       <td>6</td>
#       <td>6.82%</td>
#     </tr>
#     <tr>
#       <td>GLN[e]</td>
#       <td>EX_GLN[e]</td>
#       <td>1000</td>
#       <td>5</td>
#       <td>15.54%</td>
#     </tr>
#     <tr>
#       <td>GLY[e]</td>
#       <td>EX_GLY[e]</td>
#       <td>428.8</td>
# ...

# %% [markdown]
# ## BIOMASS CON LUZ

# %%
pvulModel.reactions.get_by_id('demandLight').upper_bound = 1000

# %%
pvulModel.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass = 0.5026775088242007</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ASN[e]</td>
#       <td>EX_ASN[e]</td>
#       <td>532.8</td>
#       <td>4</td>
#       <td>6.41%</td>
#     </tr>
#     <tr>
#       <td>BETA-D-FRUCTOSE[e]</td>
#       <td>EX_BETA-D-FRUCTOSE[e]</td>
#       <td>27.99</td>
#       <td>6</td>
#       <td>0.51%</td>
#     </tr>
#     <tr>
#       <td>GLC[e]</td>
#       <td>EX_GLC[e]</td>
#       <td>22.6</td>
#       <td>6</td>
#       <td>0.41%</td>
#     </tr>
#     <tr>
#       <td>GLN[e]</td>
#       <td>EX_GLN[e]</td>
#       <td>1000</td>
#       <td>5</td>
#       <td>15.05%</td>
#     </tr>
#     <tr>
#       <td>ILE[e]</td>
#       <td>EX_ILE[e]</td>
#       <td>1.347</td>
# ...

# %%
pvulModel.reactions.get_by_id('Biomass')
# Out:
# <Reaction Biomass at 0x287681cce20>

# %%
pvulModel.boundary
# Out:
# [<Reaction EX_STEARIC_ACID[e] at 0x1a7aba55ff0>,
#  <Reaction EX_HIS[e] at 0x1a7aba8f850>,
#  <Reaction EX_GLY[e] at 0x1a7abbe3f40>,
#  <Reaction EX_SUC[e] at 0x1a7abc819c0>,
#  <Reaction EX_LYS[e] at 0x1a7abcebdc0>,
#  <Reaction EX_PRO[e] at 0x1a7abe556c0>,
#  <Reaction EX_ASCORBATE[e] at 0x1a7abe574f0>,
#  <Reaction EX_HCO3[e] at 0x1a7abe56f80>,
#  <Reaction EX_CIT[e] at 0x1a7abe915a0>,
#  <Reaction EX_ILE[e] at 0x1a7abecd2a0>,
#  <Reaction EX_BETA-D-FRUCTOSE[e] at 0x1a7abf0f670>,
#  <Reaction EX_PHE[e] at 0x1a7abf77c40>,
#  <Reaction EX_SULFATE[e] at 0x1a7ac01fbb0>,
#  <Reaction EX_VAL[e] at 0x1a7ac05d690>,
#  <Reaction EX_PYRIDOXAL_PHOSPHATE[e] at 0x1a7ac05fd30>,
#  <Reaction EX_MAL[e] at 0x1a7ac05fa30>,
#  <Reaction EX_Pi[e] at 0x1a7ac090f10>,
#  <Reaction EX_LINOLEIC_ACID[e] at 0x1a7ac092c80>,
#  <Reaction EX_WATER[e] at 0x1a7ac093f70>,
#  <Reaction EX_LEU[e] at 0x1a7ac0cc9d0>,
#  <Reaction EX_L-ASPARTATE[e] at 0x1a7ac1106a0>,
# ...

# %%
pvulModel.reactions.get_by_id('Trans_EX_SUCROSE[e]').lower_bound = -1000 
pvulModel.reactions.get_by_id('Trans_EX_SUCROSE[e]').upper_bound = 1000
pvulModel.reactions.get_by_id('demandLight').upper_bound = 1000

# %%
pvulModel.metabolites.get_by_id('SUCROSE[e]')
# Out:
# <Metabolite SUCROSE[e] at 0x1a7ab7ba5f0>

# %%
pvulModel.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass = 0.5026775088242007</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ASN[e]</td>
#       <td>EX_ASN[e]</td>
#       <td>532.8</td>
#       <td>4</td>
#       <td>6.41%</td>
#     </tr>
#     <tr>
#       <td>BETA-D-FRUCTOSE[e]</td>
#       <td>EX_BETA-D-FRUCTOSE[e]</td>
#       <td>27.99</td>
#       <td>6</td>
#       <td>0.51%</td>
#     </tr>
#     <tr>
#       <td>GLC[e]</td>
#       <td>EX_GLC[e]</td>
#       <td>22.6</td>
#       <td>6</td>
#       <td>0.41%</td>
#     </tr>
#     <tr>
#       <td>GLN[e]</td>
#       <td>EX_GLN[e]</td>
#       <td>1000</td>
#       <td>5</td>
#       <td>15.05%</td>
#     </tr>
#     <tr>
#       <td>ILE[e]</td>
#       <td>EX_ILE[e]</td>
#       <td>1.347</td>
# ...

# %%
for i in pvulModel.reactions:
    if "ATPSYN" in i.id:
        print(i.id)

# %%
pvulModel.reactions.get_by_id('RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN')
# Out:
# <Reaction RIBULOSE-BISPHOSPHATE-CARBOXYLASE-RXN at 0x1a7ac323df0>
