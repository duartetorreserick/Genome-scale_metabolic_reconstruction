# %%
# %cd C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\RESULTS\MASSBALANCE
pathways = {}
with open('pathways.dat') as f:
    for line in f:
        #if line.startswith('//'):
        #    pathways[pathwayID]=listarxn
        if line.startswith('UNIQUE-ID'):
            pathwayID=line
            pathways[pathwayID]=''
            #print(pathwayID)
        elif line.startswith('REACTION-LIST'):
            listarxn.append(line)
        elif line.startswith('//'):
            pathways[pathwayID]=listarxn
            listarxn=[]
# Out:
# C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\RESULTS\MASSBALANCE

# %%
# %cd C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\RESULTS\MASSBALANCE
pathways =[]
with open('pathways.dat') as f:
    for line in f:
        #if line.startswith('//'):
        #    pathways[pathwayID]=listarxn
        if line.startswith('COMMON-NAME'):
                pathways.append(line)
len(pathways)
# Out:
# C:\Users\duart\OneDrive\Documentos\UNIANDES\PHASEOLUS LUNATUS\RESULTS\MASSBALANCE
# 501

# %%
pathways
# Out:
# {'UNIQUE-ID - PWY-6809\n': ['REACTION-LIST - RXN-8074\n',
#   'REACTION-LIST - RXN1F-155\n'],
#  'UNIQUE-ID - PWY-7985\n': ['REACTION-LIST - OXALATE--COA-LIGASE-RXN\n',
#   'REACTION-LIST - OXALYL-COA-DECARBOXYLASE-RXN\n',
#   'REACTION-LIST - FORMYL-COA-HYDROLASE-RXN\n',
#   'REACTION-LIST - 1.2.1.2-RXN\n'],
#  'UNIQUE-ID - ASPARAGINE-BIOSYNTHESIS\n': ['REACTION-LIST - ASNSYNB-RXN\n'],
#  'UNIQUE-ID - PWY-6933\n': ['REACTION-LIST - RXN-11063\n',
#   'REACTION-LIST - RXN-11061\n'],
#  'UNIQUE-ID - PWY-2861\n': ['REACTION-LIST - RXN-4705\n',
#   'REACTION-LIST - RXN-4704\n',
#   'REACTION-LIST - RXN-4703\n',
#   'REACTION-LIST - RXN-4702\n'],
#  'UNIQUE-ID - PWY-7897\n': ['REACTION-LIST - RXN-18753\n',
#   'REACTION-LIST - RXN-11467\n',
#   'REACTION-LIST - RXN-11468\n',
#   'REACTION-LIST - RXN-14069\n',
#   'REACTION-LIST - 4-COUMARATE--COA-LIGASE-RXN\n',
#   'REACTION-LIST - NARINGENIN-CHALCONE-SYNTHASE-RXN\n',
#   'REACTION-LIST - APIGNAR-RXN\n',
# ...

# %%
with open("pathways_with_rxns","w") as archivo:
    for clave, valor in pathways.items():
        linea=f"{clave}:{valor}\n"
        archivo.write(linea)

# %%
newPathways ={}
for clave, valor in pathways.items():
    newClave=clave.replace('UNIQUE-ID - ',"")
    newClave2=newClave.replace("\n","")
    newValor=[]
    for j in valor:
        newElement=j.replace("REACTION-LIST - ","")
        newElement=newElement.replace("\n","")
        newValor.append(newElement)
    newPathways[newClave2]=newValor

# %%
newPathways
# Out:
# {'PWY-6809': ['RXN-8074', 'RXN1F-155'],
#  'PWY-7985': ['OXALATE--COA-LIGASE-RXN',
#   'OXALYL-COA-DECARBOXYLASE-RXN',
#   'FORMYL-COA-HYDROLASE-RXN',
#   '1.2.1.2-RXN'],
#  'ASPARAGINE-BIOSYNTHESIS': ['ASNSYNB-RXN'],
#  'PWY-6933': ['RXN-11063', 'RXN-11061'],
#  'PWY-2861': ['RXN-4705', 'RXN-4704', 'RXN-4703', 'RXN-4702'],
#  'PWY-7897': ['RXN-18753',
#   'RXN-11467',
#   'RXN-11468',
#   'RXN-14069',
#   '4-COUMARATE--COA-LIGASE-RXN',
#   'NARINGENIN-CHALCONE-SYNTHASE-RXN',
#   'APIGNAR-RXN',
#   'RXN-18730',
#   'RXN-14076',
#   'RXN-11686',
#   'RXN-11684',
#   'RXN-11685',
#   'RXN-18727',
#   'RXN-18725',
#   'RXN-18724'],
#  'PWY-1269': ['RXN-16804',
#   'DARAB5PISOM-RXN',
#   'KDO-8PSYNTH-RXN',
#   'KDO-8PPHOSPHAT-RXN',
#   'CPM-KDOSYNTH-RXN'],
#  'PWY-7184': ['THYMIDYLATESYN-RXN',
#   'RXN-12195',
#   'CDPREDUCT-RXN',
#   'UDPREDUCT-RXN',
#   'DTDPKIN-RXN',
#   'DTMPKI-RXN',
#   'DUTP-PYROP-RXN',
#   'DUDPKIN-RXN',
#   'DCDPKIN-RXN'],
# ...
